# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt


# Load an audio file
audio_path = 'sample.wav'
y, sr = librosa.load(audio_path)

# Extract MFCCs
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

# Display the MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
def extract_mfcc_features(audio_path, n_mfcc=13):
    y, sr = librosa.load(audio_path)
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return mfccs.T  # Transpose to have time steps as rows

# Suppose you have a dataset with audio paths and labels
dataset = [
    ('sample.wav', 'label1'),
]

# Extract MFCC features and labels
X = []
y = []
for audio_path, label in dataset:
    mfccs = extract_mfcc_features(audio_path)
    X.append(mfccs)
    y.append(label)

print(X)
print(y)
# Out:
# [array([[-546.45825  ,   45.452805 ,   15.193655 , ...,    5.6030188,
#           11.373831 ,    6.7094464],
#        [-354.09122  ,  132.69354  ,   -4.0842605, ...,    4.3416176,
#            9.017996 ,    6.41969  ],
#        [-269.12793  ,  133.39233  ,   -3.864286 , ...,    2.2946577,
#            4.7155123,    6.5221148],
#        ...,
#        [-534.41565  ,   68.621056 ,   45.247494 , ...,    6.429479 ,
#            4.469661 ,    1.6731473],
#        [-578.56757  ,   15.912218 ,   14.773604 , ...,    6.7950377,
#            6.260383 ,    5.3711443],
#        [-590.10864  ,    0.       ,    0.       , ...,    0.       ,
#            0.       ,    0.       ]], dtype=float32)]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 20
#      17     y.append(label)
#      19 print(X)
# ---> 20 print(Y)
#
# NameError: name 'Y' is not defined
